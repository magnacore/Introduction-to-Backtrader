# %%
#!pip install backtrader

# %%
from datetime import datetime
import backtrader as bt
import matplotlib

matplotlib.__version__
# Out:
# '3.2.2'

# %%
cerebro = bt.Cerebro()

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    
    params = (
        ('maperiod_fast', 8),
        ('maperiod_slow', 34),
    )

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        
        # To keep track of pending orders
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
        # Add a MovingAverageSimple indicator
        self.sma_fast = bt.indicators.ExponentialMovingAverage(self.datas[0], period=self.params.maperiod_fast)
        self.sma_slow = bt.indicators.ExponentialMovingAverage(self.datas[0], period=self.params.maperiod_slow)

    def log(self, txt, dt=None):
        '''Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print(f'{dt.isoformat()}, {txt}')
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return
        
        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED, Price: {order.executed.price}, Cost: {order.executed.value}, Comm {order.executed.comm}')
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm 
            elif order.issell():
                self.log(f'SELL EXECUTED, Price: {order.executed.price}, Cost: {order.executed.value}, Comm {order.executed.comm}')
    
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Reset order status to prepare for next order
        self.order = None
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log(f'OPERATION PROFIT, GROSS: {trade.pnl}, NET: {trade.pnlcomm}')

    def next(self):
        # Simply log the closing price of the series from the reference
        # self.log(f'Close, {self.dataclose[0]}')

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.sma_fast[0] < self.sma_slow[0]:

                
                self.log(f'SELL CREATE, {self.dataclose[0]}')

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

        else:

            if self.sma_fast[0] > self.sma_slow[0]:
                
                self.log(f'BUY CREATE, {self.dataclose[0]}')

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

# %%
# Add a strategy
cerebro.addstrategy(TestStrategy)
# Out:
# 0

# %%
data = bt.feeds.YahooFinanceData(dataname='^NSEI', fromdate=datetime(2010, 1, 1),
                                  todate=datetime(2021, 2, 16))
cerebro.adddata(data)

# %%
cerebro.broker.setcash(10_00_000.0)

# %%
# Add a FixedSize sizer according to the stake
cerebro.addsizer(bt.sizers.FixedSize, stake=3) #buy/sell 3 futures

# %%
# Set the commission - Rs 20 per transcation
cerebro.broker.setcommission(commission=20, margin=1_70_000)

# %%
starting = cerebro.broker.getvalue()
print(f'Starting Portfolio Value: {starting}')
# Out:
# Starting Portfolio Value: 1000000.0

# %%
# %%time
cerebro.run()
# Out:
# 2010-02-22, SELL CREATE, 4856.4
# 2010-02-23, SELL EXECUTED, Price: 4856.6, Cost: 510000.0, Comm 60.0
# 2010-03-08, BUY CREATE, 5124.0
# 2010-03-09, BUY EXECUTED, Price: 5121.05, Cost: 510000.0, Comm 60.0
# 2010-03-09, OPERATION PROFIT, GROSS: -793.3499999999995, NET: -913.3499999999995
# 2010-05-05, SELL CREATE, 5124.9
# 2010-05-06, SELL EXECUTED, Price: 5124.4, Cost: 510000.0, Comm 60.0
# 2010-06-14, BUY CREATE, 5197.7
# 2010-06-15, BUY EXECUTED, Price: 5201.3, Cost: 510000.0, Comm 60.0
# 2010-06-15, OPERATION PROFIT, GROSS: -230.70000000000164, NET: -350.70000000000164
# 2010-11-19, SELL CREATE, 5890.3
# 2010-11-22, SELL EXECUTED, Price: 5920.899999999999, Cost: 510000.0, Comm 60.0
# 2010-12-24, BUY CREATE, 6011.6
# 2010-12-27, BUY EXECUTED, Price: 6013.3, Cost: 510000.0, Comm 60.0
# 2010-12-27, OPERATION PROFIT, GROSS: -277.20000000000437, NET: -397.20000000000437
# 2011-01-10, SELL CREATE, 5762.85
# 2011-01-11, SELL EXECUTED, Price: 5767.95, Cost: 510000.0, Comm 60.0
# 2011-03-25, BUY CREATE, 5654.25
# 2011-03-28, BUY EXECUTED, Price: 5645.25, Cost: 510000.0, Comm 60.0
# 2011-03-28, OPERATION PROFIT, GROSS: 368.09999999999945, NET: 248.09999999999945
# 2011-05-04, SELL CREATE, 5537.15
# 2011-05-05, SELL EXECUTED, Price: 5531.600000000001, Cost: 510000.0, Comm 60.0
# 2011-06-30, BUY CREATE, 5647.4
# 2011-07-01, BUY EXECUTED, Price: 5705.75, Cost: 510000.0, Comm 60.0
# 2011-07-01, OPERATION PROFIT, GROSS: -522.4499999999962, NET: -642.4499999999962
# 2011-07-29, SELL CREATE, 5482.0
# 2011-08-01, SELL EXECUTED, Price: 5527.5, Cost: 510000.0, Comm 60.0
# 2011-10-14, BUY CREATE, 5132.3
# 2011-10-17, BUY EXECUTED, Price: 5156.2, Cost: 510000.0, Comm 60.0
# 2011-10-17, OPERATION PROFIT, GROSS: 1113.9000000000005, NET: 993.9000000000005
# 2011-11-17, SELL CREATE, 4934.75
# 2011-11-18, SELL EXECUTED, Price: 4899.15, Cost: 510000.0, Comm 60.0
# 2012-01-16, BUY CREATE, 4873.9
# 2012-01-17, BUY EXECUTED, Price: 4904.5, Cost: 510000.0, Comm 60.0
# 2012-01-17, OPERATION PROFIT, GROSS: -16.05000000000109, NET: -136.0500000000011
# 2012-03-26, SELL CREATE, 5184.25
# 2012-03-27, SELL EXECUTED, Price: 5242.95, Cost: 510000.0, Comm 60.0
# 2012-04-04, BUY CREATE, 5322.9
# 2012-04-09, BUY EXECUTED, Price: 5282.5, Cost: 510000.0, Comm 60.0
# 2012-04-09, OPERATION PROFIT, GROSS: -118.65000000000055, NET: -238.65000000000055
# 2012-04-09, SELL CREATE, 5234.4
# 2012-04-10, SELL EXECUTED, Price: 5254.1, Cost: 510000.0, Comm 60.0
# 2012-04-19, BUY CREATE, 5332.4
# 2012-04-20, BUY EXECUTED, Price: 5313.95, Cost: 510000.0, Comm 60.0
# 2012-04-20, OPERATION PROFIT, GROSS: -179.54999999999836, NET: -299.54999999999836
# 2012-04-23, SELL CREATE, 5200.6
# 2012-04-24, SELL EXECUTED, Price: 5215.9, Cost: 510000.0, Comm 60.0
# 2012-06-13, BUY CREATE, 5121.45
# 2012-06-14, BUY EXECUTED, Price: 5105.1, Cost: 510000.0, Comm 60.0
# 2012-06-14, OPERATION PROFIT, GROSS: 332.3999999999978, NET: 212.39999999999782
# 2012-07-25, SELL CREATE, 5109.6
# 2012-07-26, SELL EXECUTED, Price: 5126.3, Cost: 510000.0, Comm 60.0
# 2012-08-01, BUY CREATE, 5240.5
# 2012-08-02, BUY EXECUTED, Price: 5233.1, Cost: 510000.0, Comm 60.0
# 2012-08-02, OPERATION PROFIT, GROSS: -320.40000000000055, NET: -440.40000000000055
# 2012-09-06, SELL CREATE, 5238.4
# 2012-09-07, SELL EXECUTED, Price: 5309.45, Cost: 510000.0, Comm 60.0
# 2012-09-07, BUY CREATE, 5342.1
# 2012-09-10, BUY EXECUTED, Price: 5361.9, Cost: 510000.0, Comm 60.0
# 2012-09-10, OPERATION PROFIT, GROSS: -157.34999999999945, NET: -277.34999999999945
# 2012-11-20, SELL CREATE, 5571.55
# 2012-11-21, SELL EXECUTED, Price: 5582.5, Cost: 510000.0, Comm 60.0
# 2012-11-27, BUY CREATE, 5727.45
# 2012-11-29, BUY EXECUTED, Price: 5736.7, Cost: 510000.0, Comm 60.0
# 2012-11-29, OPERATION PROFIT, GROSS: -462.59999999999945, NET: -582.5999999999995
# 2013-02-08, SELL CREATE, 5903.5
# 2013-02-11, SELL EXECUTED, Price: 5920.05, Cost: 510000.0, Comm 60.0
# 2013-04-23, BUY CREATE, 5836.9
# 2013-04-25, BUY EXECUTED, Price: 5856.100000000001, Cost: 510000.0, Comm 60.0
# 2013-04-25, OPERATION PROFIT, GROSS: 191.84999999999945, NET: 71.84999999999945
# 2013-06-07, SELL CREATE, 5881.0
# 2013-06-10, SELL EXECUTED, Price: 5907.899999999999, Cost: 510000.0, Comm 60.0
# 2013-07-11, BUY CREATE, 5935.1
# 2013-07-12, BUY EXECUTED, Price: 6000.5, Cost: 510000.0, Comm 60.0
# 2013-07-12, OPERATION PROFIT, GROSS: -277.8000000000038, NET: -397.8000000000038
# 2013-07-30, SELL CREATE, 5755.05
# 2013-07-31, SELL EXECUTED, Price: 5738.350000000001, Cost: 510000.0, Comm 60.0
# 2013-09-11, BUY CREATE, 5913.15
# 2013-09-12, BUY EXECUTED, Price: 5931.149999999999, Cost: 510000.0, Comm 60.0
# 2013-09-12, OPERATION PROFIT, GROSS: -578.3999999999951, NET: -698.3999999999951
# 2014-01-10, SELL CREATE, 6171.45
# 2014-01-13, SELL EXECUTED, Price: 6189.55, Cost: 510000.0, Comm 60.0
# 2014-01-13, BUY CREATE, 6272.75
# 2014-01-14, BUY EXECUTED, Price: 6260.25, Cost: 510000.0, Comm 60.0
# 2014-01-14, OPERATION PROFIT, GROSS: -212.09999999999945, NET: -332.09999999999945
# 2014-01-29, SELL CREATE, 6120.25
# 2014-01-30, SELL EXECUTED, Price: 6067.0, Cost: 510000.0, Comm 60.0
# 2014-02-26, BUY CREATE, 6238.8
# 2014-02-28, BUY EXECUTED, Price: 6228.45, Cost: 510000.0, Comm 60.0
# 2014-02-28, OPERATION PROFIT, GROSS: -484.34999999999945, NET: -604.3499999999995
# 2014-10-08, SELL CREATE, 7842.7
# 2014-10-09, SELL EXECUTED, Price: 7886.5, Cost: 510000.0, Comm 60.0
# 2014-10-28, BUY CREATE, 8027.6
# 2014-10-29, BUY EXECUTED, Price: 8077.05, Cost: 510000.0, Comm 60.0
# 2014-10-29, OPERATION PROFIT, GROSS: -571.6500000000005, NET: -691.6500000000005
# 2014-12-16, SELL CREATE, 8067.6
# 2014-12-17, SELL EXECUTED, Price: 8041.2, Cost: 510000.0, Comm 60.0
# 2015-01-05, BUY CREATE, 8378.4
# 2015-01-06, BUY EXECUTED, Price: 8325.3, Cost: 510000.0, Comm 60.0
# 2015-01-06, OPERATION PROFIT, GROSS: -852.2999999999984, NET: -972.2999999999984
# 2015-01-06, SELL CREATE, 8127.35
# 2015-01-07, SELL EXECUTED, Price: 8118.649999999999, Cost: 510000.0, Comm 60.0
# 2015-01-15, BUY CREATE, 8494.15
# 2015-01-16, BUY EXECUTED, Price: 8504.05, Cost: 510000.0, Comm 60.0
# 2015-01-16, OPERATION PROFIT, GROSS: -1156.2000000000016, NET: -1276.2000000000016
# 2015-03-18, SELL CREATE, 8685.9
# 2015-03-19, SELL EXECUTED, Price: 8749.45, Cost: 510000.0, Comm 60.0
# 2015-04-09, BUY CREATE, 8778.3
# 2015-04-10, BUY EXECUTED, Price: 8774.35, Cost: 510000.0, Comm 60.0
# 2015-04-10, OPERATION PROFIT, GROSS: -74.69999999999891, NET: -194.6999999999989
# 2015-04-20, SELL CREATE, 8448.1
# 2015-04-21, SELL EXECUTED, Price: 8416.1, Cost: 510000.0, Comm 60.0
# 2015-06-24, BUY CREATE, 8360.85
# 2015-06-25, BUY EXECUTED, Price: 8336.25, Cost: 510000.0, Comm 60.0
# 2015-06-25, OPERATION PROFIT, GROSS: 239.5500000000011, NET: 119.55000000000109
# 2015-08-20, SELL CREATE, 8372.75
# 2015-08-21, SELL EXECUTED, Price: 8305.4, Cost: 510000.0, Comm 60.0
# 2015-10-07, BUY CREATE, 8177.4
# 2015-10-08, BUY EXECUTED, Price: 8196.75, Cost: 510000.0, Comm 60.0
# 2015-10-08, OPERATION PROFIT, GROSS: 325.9499999999989, NET: 205.9499999999989
# 2015-11-04, SELL CREATE, 8040.2
# 2015-11-05, SELL EXECUTED, Price: 8030.350000000001, Cost: 510000.0, Comm 60.0
# 2015-12-29, BUY CREATE, 7928.95
# 2015-12-30, BUY EXECUTED, Price: 7938.600000000001, Cost: 510000.0, Comm 60.0
# 2015-12-30, OPERATION PROFIT, GROSS: 275.25000000000273, NET: 155.25000000000273
# 2016-01-05, SELL CREATE, 7784.65
# 2016-01-06, SELL EXECUTED, Price: 7788.05, Cost: 510000.0, Comm 60.0
# 2016-03-08, BUY CREATE, 7485.3
# 2016-03-09, BUY EXECUTED, Price: 7436.100000000001, Cost: 510000.0, Comm 60.0
# 2016-03-09, OPERATION PROFIT, GROSS: 1055.8499999999995, NET: 935.8499999999995
# 2016-09-30, SELL CREATE, 8611.15
# 2016-10-03, SELL EXECUTED, Price: 8666.15, Cost: 510000.0, Comm 60.0
# 2016-10-03, BUY CREATE, 8738.1
# 2016-10-04, BUY EXECUTED, Price: 8770.0, Cost: 510000.0, Comm 60.0
# 2016-10-04, OPERATION PROFIT, GROSS: -311.5500000000011, NET: -431.5500000000011
# 2016-10-13, SELL CREATE, 8573.35
# 2016-10-14, SELL EXECUTED, Price: 8594.0, Cost: 510000.0, Comm 60.0
# 2017-01-06, BUY CREATE, 8243.8
# 2017-01-09, BUY EXECUTED, Price: 8259.35, Cost: 510000.0, Comm 60.0
# 2017-01-09, OPERATION PROFIT, GROSS: 1003.9499999999989, NET: 883.9499999999989
# 2017-08-21, SELL CREATE, 9754.35
# 2017-08-22, SELL EXECUTED, Price: 9815.75, Cost: 510000.0, Comm 60.0
# 2017-08-28, BUY CREATE, 9912.8
# 2017-08-29, BUY EXECUTED, Price: 9886.4, Cost: 510000.0, Comm 60.0
# 2017-08-29, OPERATION PROFIT, GROSS: -211.9499999999989, NET: -331.9499999999989
# 2017-08-29, SELL CREATE, 9796.05
# 2017-08-30, SELL EXECUTED, Price: 9859.5, Cost: 510000.0, Comm 60.0
# 2017-08-30, BUY CREATE, 9884.4
# 2017-08-31, BUY EXECUTED, Price: 9905.7, Cost: 510000.0, Comm 60.0
# 2017-08-31, OPERATION PROFIT, GROSS: -138.60000000000218, NET: -258.6000000000022
# 2017-09-27, SELL CREATE, 9735.75
# 2017-09-28, SELL EXECUTED, Price: 9736.4, Cost: 510000.0, Comm 60.0
# 2017-10-10, BUY CREATE, 10016.95
# 2017-10-11, BUY EXECUTED, Price: 10042.6, Cost: 510000.0, Comm 60.0
# 2017-10-11, OPERATION PROFIT, GROSS: -918.6000000000022, NET: -1038.6000000000022
# 2017-12-04, SELL CREATE, 10127.75
# 2017-12-05, SELL EXECUTED, Price: 10118.25, Cost: 510000.0, Comm 60.0
# 2017-12-15, BUY CREATE, 10333.25
# 2017-12-18, BUY EXECUTED, Price: 10263.1, Cost: 510000.0, Comm 60.0
# 2017-12-18, OPERATION PROFIT, GROSS: -434.5500000000011, NET: -554.5500000000011
# 2018-02-09, SELL CREATE, 10454.95
# 2018-02-12, SELL EXECUTED, Price: 10518.2, Cost: 510000.0, Comm 60.0
# 2018-04-12, BUY CREATE, 10458.65
# 2018-04-13, BUY EXECUTED, Price: 10495.3, Cost: 510000.0, Comm 60.0
# 2018-04-13, OPERATION PROFIT, GROSS: 68.70000000000437, NET: -51.299999999995634
# 2018-05-24, SELL CREATE, 10513.85
# 2018-05-25, SELL EXECUTED, Price: 10533.05, Cost: 510000.0, Comm 60.0
# 2018-05-28, BUY CREATE, 10688.65
# 2018-05-29, BUY EXECUTED, Price: 10689.4, Cost: 510000.0, Comm 60.0
# 2018-05-29, OPERATION PROFIT, GROSS: -469.0500000000011, NET: -589.0500000000011
# 2018-09-19, SELL CREATE, 11234.35
# 2018-09-21, SELL EXECUTED, Price: 11271.299999999997, Cost: 510000.0, Comm 60.0
# 2018-11-19, BUY CREATE, 10763.4
# 2018-11-20, BUY EXECUTED, Price: 10740.1, Cost: 510000.0, Comm 60.0
# 2018-11-20, OPERATION PROFIT, GROSS: 1593.5999999999913, NET: 1473.5999999999913
# 2018-12-11, SELL CREATE, 10549.15
# 2018-12-12, SELL EXECUTED, Price: 10591.0, Cost: 510000.0, Comm 60.0
# 2018-12-12, BUY CREATE, 10737.6
# 2018-12-13, BUY EXECUTED, Price: 10810.75, Cost: 510000.0, Comm 60.0
# 2018-12-13, OPERATION PROFIT, GROSS: -659.25, NET: -779.25
# 2019-01-29, SELL CREATE, 10652.2
# 2019-01-30, SELL EXECUTED, Price: 10702.25, Cost: 510000.0, Comm 60.0
# 2019-02-01, BUY CREATE, 10893.65
# 2019-02-04, BUY EXECUTED, Price: 10876.75, Cost: 510000.0, Comm 60.0
# 2019-02-04, OPERATION PROFIT, GROSS: -523.5, NET: -643.5
# 2019-02-18, SELL CREATE, 10640.95
# 2019-02-19, SELL EXECUTED, Price: 10636.7, Cost: 510000.0, Comm 60.0
# 2019-03-01, BUY CREATE, 10863.5
# 2019-03-05, BUY EXECUTED, Price: 10864.85, Cost: 510000.0, Comm 60.0
# 2019-03-05, OPERATION PROFIT, GROSS: -684.4499999999989, NET: -804.4499999999989
# 2019-05-10, SELL CREATE, 11278.9
# 2019-05-13, SELL EXECUTED, Price: 11258.700000000003, Cost: 510000.0, Comm 60.0
# 2019-05-21, BUY CREATE, 11709.1
# 2019-05-22, BUY EXECUTED, Price: 11727.950000000003, Cost: 510000.0, Comm 60.0
# 2019-05-22, OPERATION PROFIT, GROSS: -1407.7499999999945, NET: -1527.7499999999945
# 2019-07-09, SELL CREATE, 11555.9
# 2019-07-10, SELL EXECUTED, Price: 11536.15, Cost: 510000.0, Comm 60.0
# 2019-09-23, BUY CREATE, 11600.2
# 2019-09-24, BUY EXECUTED, Price: 11590.700000000003, Cost: 510000.0, Comm 60.0
# 2019-09-24, OPERATION PROFIT, GROSS: -163.65000000000327, NET: -283.6500000000033
# 2020-01-30, SELL CREATE, 12035.8
# 2020-01-31, SELL EXECUTED, Price: 12100.4, Cost: 510000.0, Comm 60.0
# 2020-02-13, BUY CREATE, 12174.65
# 2020-02-14, BUY EXECUTED, Price: 12190.15, Cost: 510000.0, Comm 60.0
# 2020-02-14, OPERATION PROFIT, GROSS: -269.25, NET: -389.25
# 2020-02-17, SELL CREATE, 12045.8
# 2020-02-18, SELL EXECUTED, Price: 12028.25, Cost: 510000.0, Comm 60.0
# 2020-05-29, BUY CREATE, 9580.3
# 2020-06-01, BUY EXECUTED, Price: 9726.85, Cost: 510000.0, Comm 60.0
# 2020-06-01, OPERATION PROFIT, GROSS: 6904.199999999999, NET: 6784.199999999999
# 2020-09-24, SELL CREATE, 10805.55
# 2020-09-25, SELL EXECUTED, Price: 10910.4, Cost: 510000.0, Comm 60.0
# 2020-10-05, BUY CREATE, 11503.35
# 2020-10-06, BUY EXECUTED, Price: 11603.450000000003, Cost: 510000.0, Comm 60.0
# 2020-10-06, OPERATION PROFIT, GROSS: -2079.1500000000033, NET: -2199.1500000000033
# CPU times: user 946 ms, sys: 24.6 ms, total: 970 ms
# Wall time: 3.83 s

# %%
ending = cerebro.broker.getvalue()
print(f'Final Portfolio Value: {ending}')
# Out:
# Final Portfolio Value: 992756.1999999997

# %%
print(f'Returns: {round(((ending - starting)/starting)*100, 2)}%')
# Out:
# Returns: -0.72%

# %%
cerebro.plot()
# Out:
# <img src="data:image/png;base64,..." width="852.75">
# [[<Figure size 640x480 with 4 Axes>]]
